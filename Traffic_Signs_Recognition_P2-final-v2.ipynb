# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
# ## Deep Learning
#
# ## Project: Build a Traffic Sign Recognition Classifier
#
# In this notebook, a template is provided for you to implement your functionality in stages which is required to successfully complete this project. If additional code is required that cannot be included in the notebook, be sure that the Python code is successfully imported and included in your submission, if necessary. Sections that begin with **'Implementation'** in the header indicate where you should begin your implementation for your project. Note that some sections of implementation are optional, and will be marked with **'Optional'** in the header.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut. In addition, Markdown cells can be edited by typically double-clicking the cell to enter edit mode.

# %% [markdown]
# ---
# ## Step -1: Required libaries, packages

# %%
# Import important packages/libraries
import numpy as np
import tensorflow as tf
import pickle
import matplotlib.pyplot as plt
import random
import csv
from sklearn.utils import shuffle
from tensorflow.contrib.layers import flatten
from skimage import transform as transf
from sklearn.cross_validation import train_test_split
import cv2
from prettytable import PrettyTable
# %matplotlib inline

SEED = 22

# %% [markdown]
# ---
# ## Step 0: Load The Data

# %%
# Load pickled data
import pickle

training_file = 'data/train.p'
validing_file = 'data/valid.p'
testing_file = 'data/test.p'

with open(training_file, mode='rb') as f:
    train = pickle.load(f)

with open(validing_file, mode='rb') as f:
    valid = pickle.load(f)
    
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)

  
X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %% [markdown]
# ---
#
# ## Step 1: Dataset Summary & Exploration
#
# The pickled data is a dictionary with 4 key/value pairs:
#
# - `'features'` is a 4D array containing raw pixel data of the traffic sign images, (num examples, width, height, channels).
# - `'labels'` is a 2D array containing the label/class id of the traffic sign. The file `signnames.csv` contains id -> name mappings for each id.
# - `'sizes'` is a list containing tuples, (width, height) representing the the original width and height the image.
# - `'coords'` is a list containing tuples, (x1, y1, x2, y2) representing coordinates of a bounding box around the sign in the image. **THESE COORDINATES ASSUME THE ORIGINAL IMAGE. THE PICKLED DATA CONTAINS RESIZED VERSIONS (32 by 32) OF THESE IMAGES**
#
# Complete the basic data summary below.

# %% [markdown]
# Visualize the German Traffic Signs Dataset using the pickled file(s). This is open ended, suggestions include: plotting traffic sign images, plotting the count of each sign, etc.
#
# The [Matplotlib](http://matplotlib.org/) [examples](http://matplotlib.org/examples/index.html) and [gallery](http://matplotlib.org/gallery.html) pages are a great resource for doing visualizations in Python.
#
# **NOTE:** It's recommended you start with something simple first. If you wish to do more, come back to it after you've completed the rest of the sections.

# %%
# TODO: Number of training examples
n_train = len(X_train)

# TODO: Number of testing examples.
#n_test = len(X_test)

# TODO: What's the shape of an traffic sign image?
_, IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH = X_train.shape
image_shape = (IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH)


# TODO: How many unique classes/labels there are in the dataset.
with open( 'signnames.csv', 'r' ) as sign_name:
    reader = csv.reader(sign_name)
    sign_names = list(reader)

sign_names = sign_names[1::] #Remove csv header
NUM_CLASSES = len(sign_names)
print('Total number of classes: {}'.format(NUM_CLASSES) )

n_classes = len( np.unique(y_train) )
assert (NUM_CLASSES == n_classes), '1 or more class(es) not represented in training set'

n_test = len(y_test)

print("Number of training examples =", n_train)
print("Number of testing examples =", n_test)
print("Image data shape =", image_shape)
print("Number of classes =", n_classes)
# Out:
# Total number of classes: 43
# Number of training examples = 34799
# Number of testing examples = 12630
# Image data shape = (32, 32, 3)
# Number of classes = 43

# %%
### DATA EXPLORATION: visualization

def visualize_random_images(list_imgs, X_dataset, y_dataset):
    '''
    list_imgs = list of index of images to be visualized
    '''
    _, ax = plt.subplots( len(list_imgs)//5, 5, figsize=(20,10))
    row, col = 0, 0  
    for idx in list_imgs:
        img = X_dataset[idx]
        ax[row, col].imshow(img)
        ax[row, col].annotate(int(y_dataset[idx]), xy=(2, 5), color='red', fontsize='20')

        ax[row,col].axis('off')
        col += 1
        if col == 5:
            row += 1
            col = 0
    plt.show()

# Visualize 20 examples picked randomly from train dataset
ls = [random.randint(0, len(y_train)) for i in range(20)]
visualize_random_images(list_imgs=ls, X_dataset=X_train, y_dataset=y_train)

# %%
### DATA EXPLORATION : class distribution

assert (NUM_CLASSES == len( np.unique(y_train) )), '1 or more class(es) not represented in training set'
        
def get_count_imgs_per_class(y, verbose=False):
    num_classes = len(np.unique(y))
    count_imgs_per_class = np.zeros( num_classes )

    for this_class in range( num_classes ):
        if verbose: 
            print('class {} | count {}'.format(this_class, np.sum( y  == this_class )) )
        count_imgs_per_class[this_class] = np.sum(y == this_class )
    #sanity check
    return count_imgs_per_class


class_freq = get_count_imgs_per_class(y_train)
print('------- ')
print('Highest count: {} (class {})'.format(np.max(class_freq), np.argmax(class_freq)))
print('Lowest count: {} (class {})'.format(np.min(class_freq), np.argmin(class_freq)))
print('------- ')
plt.bar(np.arange(NUM_CLASSES), class_freq , align='center')
plt.xlabel('class')
plt.ylabel('Frequency')
plt.xlim([-1, 43])
plt.title("class frequency in Training set")
plt.show()

sign_name_table = PrettyTable()
sign_name_table.field_names = ['class value', 'Name of Traffic sign']
for i in range(len(sign_names)):
    sign_name_table.add_row([sign_names[i][0], sign_names[i][1]] )
    
print(sign_name_table)
# Out:
# -------
# Highest count: 2010.0 (class 2)
# Lowest count: 180.0 (class 0)
# -------
# +-------------+----------------------------------------------------+
# | class value |                Name of Traffic sign                |
# +-------------+----------------------------------------------------+
# |      0      |                Speed limit (20km/h)                |
# |      1      |                Speed limit (30km/h)                |
# |      2      |                Speed limit (50km/h)                |
# |      3      |                Speed limit (60km/h)                |
# |      4      |                Speed limit (70km/h)                |
# |      5      |                Speed limit (80km/h)                |
# |      6      |            End of speed limit (80km/h)             |
# |      7      |               Speed limit (100km/h)                |
# |      8      |               Speed limit (120km/h)                |
# |      9      |                     No passing                     |
# |      10     |    No passing for vechiles over 3.5 metric tons    |
# |      11     |       Right-of-way at the next intersection        |
# |      12     |                   Priority road                    |
# |      13     |                       Yield                        |
# |      14     |                        Stop                        |
# |      15     |                    No vechiles                     |
# |      16     |      Vechiles over 3.5 metric tons prohibited      |
# |      17     |                      No entry                      |
# |      18     |                  General caution                   |
# |      19     |            Dangerous curve to the left             |
# |      20     |            Dangerous curve to the right            |
# |      21     |                    Double curve                    |
# |      22     |                     Bumpy road                     |
# |      23     |                   Slippery road                    |
# |      24     |             Road narrows on the right              |
# |      25     |                     Road work                      |
# |      26     |                  Traffic signals                   |
# |      27     |                    Pedestrians                     |
# |      28     |                 Children crossing                  |
# |      29     |                 Bicycles crossing                  |
# |      30     |                 Beware of ice/snow                 |
# |      31     |               Wild animals crossing                |
# |      32     |        End of all speed and passing limits         |
# |      33     |                  Turn right ahead                  |
# |      34     |                  Turn left ahead                   |
# |      35     |                     Ahead only                     |
# |      36     |                Go straight or right                |
# |      37     |                Go straight or left                 |
# |      38     |                     Keep right                     |
# |      39     |                     Keep left                      |
# |      40     |                Roundabout mandatory                |
# |      41     |                 End of no passing                  |
# |      42     | End of no passing by vechiles over 3.5 metric tons |
# +-------------+----------------------------------------------------+

# %%
### DATA EXPLORATION: Pixel intensity distribution

def histograms_randImgs(label, channel, n_imgs=5, ylim=50):
    '''
    Histogram (pixel intensity distribution) for a selection of images with the same label.
    For better visualization, the images are shown in grayscale
    label - the label of the images
    n_imgs - number of images to show (default=5)
    channel - channel used to compute histogram
    ylim - range of y axis values for histogram plot (default=50)
    ''' 
    #randonly select n images
    assert channel < 3, 'images are RGB, choose channel value between in the range [0, 2]'
    assert (np.sum(y_train==label)) >= n_imgs, 'reduce your number of images'
    #find all images with the selected label
    all_imgs = np.ravel( np.argwhere(y_train==label) )
    # pick 5 images randomly
    ls_idx =  np.random.choice( all_imgs, size=n_imgs, replace=False)
    _, ax = plt.subplots( n_imgs, 2, figsize=(10,10))
    print('Histogram of selected images from the class {}  ......'.format(label))
    row, col = 0, 0  
    for idx in ls_idx:
        img = X_train[idx, :, :, channel]
        #display image
        ax[row, col].imshow(img, cmap='gray')
        ax[row,col].axis('off')
        #display histogram
        hist = np.histogram(img, bins=256)
        ax[row, col + 1].hist(hist, bins=256)
        ax[row, col + 1].set_xlim([0, 100])
        ax[row, col + 1].set_ylim([0, ylim])
        #initialize col, row value
        col = 0
        row += 1
    plt.show()

histograms_randImgs(38, 1)
# Out:
# Histogram of selected images from the class 38  ......

# %% [markdown]
# ### Comments:
#
# Below are the most common variations that I noticed when comparing the images in the dataset:
#
# 1. Variation of illumination (brightness/contrast).
# 2. Different filling factor, i.e the size of the sign versus the image size.
# 3. Variation of the background scenery and color.
# 4. Images from the same class can have very different histogram.
#
# Also, in the same image there are similar variations. In particular, the brightness/contrast, the background are not uniform.
#
# The label distribution is not uniform. The "majority" classes are class 1, 2, 11, 12 which are respectively: Speed limit (30km/h), Speed limit (50km/h), Right-of-way at the next intersection and Priority road.

# %%
def random_transform(img, angle_range=[-10, 10],
                     scale_range=[0.8, 1.2], 
                     translation_range=[-3, 3]):
    '''
    The function takes an image and performs a set of random affine transformations.
    img - original image
    ang_range - angular range of the rotation [-15,+15] deg for example
    scale_range - [0.8, 1.2]
    shear_range - [10,-10]
    translation_range : [-2, 2]
    '''
    img_height, img_width, img_depth = img.shape
    
    # Generate random parameter values
    angle_value = np.random.uniform(low=angle_range[0], high=angle_range[1], size=None)
    scaleX = np.random.uniform(low=scale_range[0], high=scale_range[1], size=None)
    scaleY = np.random.uniform(low=scale_range[0], high=scale_range[1], size=None)
    translationX = np.random.randint(low=translation_range[0], high=translation_range[1]+1, size=None)
    translationY = np.random.randint(low=translation_range[0], high=translation_range[1]+1, size=None)

    #center images to run rotation about the image center rather than [0,0] point
    center_shift = np.array( [img_height, img_width] ) / 2. -0.5
    #transformation translation of the image: image center matches [0,0] orign
    transform_center = transf.SimilarityTransform( translation = -center_shift )
    transform_uncenter = transf.SimilarityTransform( translation = center_shift )

    # Image transformation : includes rotation, shear, tranlation, zoom
    transform_aug = transf.AffineTransform( rotation = np.deg2rad( angle_value ),
                                         scale = (1/scaleY, 1/scaleX),
                                         translation = (translationY, translationX))

    # Make transformation
    full_transform = transform_center + transform_aug + transform_uncenter
    new_img = transf.warp( img, full_transform, preserve_range=True )
    
    return new_img.astype('uint8')


def data_augmentation(X_dataset, y_dataset, augm_nbr, keep_dist = True):
    '''
    X_dataset - image dataset to augment
    y_dataset - label dataset
    keep_dist - True: keep class distribution of original dataset,
                False: balance dataset,
    augm_param - is the augmentation parameter
                if keep_dist is True, increase the dataset by the factor 'augm_nbr' (2x, 5x or 10x...)
                if keep_dist is False, make all classes have same number of images: 'augm_nbr' (2500, 3000 or 4000 imgs)
    
    '''
    #X_train_dtype = X_train
    n_classes = len(np.unique(y_dataset)) #number of classes in dataset
    _, img_height, img_width, img_depth = X_dataset.shape
    class_freq = get_count_imgs_per_class(y_dataset)
    print(class_freq)
    
    if keep_dist:
        extra_imgs_per_class = np.array([augm_nbr*x for x in class_freq])
        
    else:
        assert (augm_nbr > np.argmax(class_freq)), 'augm_nbr must be larger than the highest class count'
        extra_imgs_per_class = augm_nbr - class_freq 
    
    total_extra_imgs = np.sum( extra_imgs_per_class )
    print(total_extra_imgs)
    #if extra images needed --> run the data augmentation op 
    if total_extra_imgs > 0:
        # initialize tensor to store extra imgs, datatype same as 
        X_extra = np.zeros( ( int(total_extra_imgs), img_height, img_width, img_depth ), dtype=X_train.dtype)
        y_extra = np.zeros( int(total_extra_imgs) )
        start_idx = 0
        print('start data augmentation .....')
        for this_class in range( n_classes ):
            print('\t Class {} | Number of extra imgs {}'.format(this_class, int(extra_imgs_per_class[this_class])))
            n_extra_imgs = extra_imgs_per_class[this_class] #number of extra images to generate for this class
        
            end_idx = start_idx + n_extra_imgs
        
            if n_extra_imgs > 0:
                #get ids of all images belonging to this_class
                all_imgs_id = np.argwhere( y_dataset == this_class )
                # initialize tensor to store all the extra images for this class 
                new_imgs_x = np.zeros( ( int(n_extra_imgs), img_height, img_width, img_depth ) )
            
                for k in range( int(n_extra_imgs) ):
                    #randomly pick an original image belonging to this_class:
                    rand_id = np.random.choice( all_imgs_id[0], size=None, replace=True )
                    rand_img = X_train[rand_id]
                    #Transform image
                    new_img = random_transform( rand_img )
                    new_imgs_x[k, :, :, :] = new_img
                
                #update tensors with new images and associated labels
                X_extra[int(start_idx) : int(end_idx)] = new_imgs_x
                y_extra[int(start_idx) : int(end_idx)] = np.ones( ( int(n_extra_imgs), ) ) * this_class
                start_idx = end_idx
        return [X_extra, y_extra]
    
    else:
        return [ None, None] #similar output format as for if condition

# %%
# shuffle train dataset before split
X_train, y_train = shuffle(X_train, y_train)
_, IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH = X_train.shape

# Split into train and validation set with ratio ~3:1
# Train/Validation split must be done before data augmentation so that validation set 
# has images similar to test set (no synthetic images)
X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=0.20, random_state=SEED)
print('Train set size: {} | Validation set size: {}\n'.format(X_train.shape[0], X_validation.shape[0]))

# Run data augmentation on Train set to have uniform distribution of class
X_extra, y_extra = data_augmentation(X_train, y_train, augm_nbr=4000, keep_dist = False)
# Out:
# Train set size: 27839 | Validation set size: 6960
#
# [  145.  1604.  1598.  1007.  1416.  1318.   295.  1029.  1014.  1048.
#   1415.   922.  1513.  1557.   551.   448.   297.   791.   856.   149.
#    240.   208.   259.   357.   199.  1065.   424.   179.   387.   186.
#    310.   552.   164.   488.   286.   845.   272.   150.  1507.   205.
#    253.   162.   168.]
# 144161.0
# start data augmentation .....
# 	 Class 0 | Number of extra imgs 3855
# 	 Class 1 | Number of extra imgs 2396
# 	 Class 2 | Number of extra imgs 2402
# 	 Class 3 | Number of extra imgs 2993
# 	 Class 4 | Number of extra imgs 2584
# 	 Class 5 | Number of extra imgs 2682
# 	 Class 6 | Number of extra imgs 3705
# 	 Class 7 | Number of extra imgs 2971
# 	 Class 8 | Number of extra imgs 2986
# 	 Class 9 | Number of extra imgs 2952
# 	 Class 10 | Number of extra imgs 2585
# 	 Class 11 | Number of extra imgs 3078
# 	 Class 12 | Number of extra imgs 2487
# 	 Class 13 | Number of extra imgs 2443
# 	 Class 14 | Number of extra imgs 3449
# 	 Class 15 | Number of extra imgs 3552
# 	 Class 16 | Number of extra imgs 3703
# 	 Class 17 | Number of extra imgs 3209
# 	 Class 18 | Number of extra imgs 3144
# 	 Class 19 | Number of extra imgs 3851
# 	 Class 20 | Number of extra imgs 3760
# 	 Class 21 | Number of extra imgs 3792
# 	 Class 22 | Number of extra imgs 3741
# 	 Class 23 | Number of extra imgs 3643
# 	 Class 24 | Number of extra imgs 3801
# 	 Class 25 | Number of extra imgs 2935
# 	 Class 26 | Number of extra imgs 3576
# 	 Class 27 | Number of extra imgs 3821
# 	 Class 28 | Number of extra imgs 3613
# 	 Class 29 | Number of extra imgs 3814
# 	 Class 30 | Number of extra imgs 3690
# 	 Class 31 | Number of extra imgs 3448
# 	 Class 32 | Number of extra imgs 3836
# 	 Class 33 | Number of extra imgs 3512
# 	 Class 34 | Number of extra imgs 3714
# 	 Class 35 | Number of extra imgs 3155
# 	 Class 36 | Number of extra imgs 3728
# 	 Class 37 | Number of extra imgs 3850
# 	 Class 38 | Number of extra imgs 2493
# 	 Class 39 | Number of extra imgs 3795
# 	 Class 40 | Number of extra imgs 3747
# 	 Class 41 | Number of extra imgs 3838
# 	 Class 42 | Number of extra imgs 3832

# %%
# Visualize 20 examples picked randomly from train dataset
ls = [random.randint(0, len(y_extra)) for i in range(20)]
visualize_random_images(list_imgs=ls, X_dataset=X_extra, y_dataset=y_extra)

# %%
if X_extra is not None:
    #X_extra converted to same type as X_train (original)
    # no need to shuffle data now (will be done just before it is fed to the model)
    X_train = np.concatenate( ( X_train, X_extra.astype('uint8') ), axis=0)
    y_train = np.concatenate( (y_train, y_extra), axis=0 )
    #free some space
    del X_extra, y_extra

# %% [markdown]
# ### Visualization after data augmentation
#
# 1. Display 20 random images
# 2. show frequency of each class

# %%
ls = [random.randint(0, len(y_train)) for i in range(20)]
visualize_random_images(list_imgs=ls, X_dataset=X_train, y_dataset=y_train)

print('*** Train dataset after augmentation')
print( '\t Total Number of images in Train dataset: {}'.format( X_train.shape[0] ) )

# Check data Class distribution of merged dataset (original + extra)
plt.bar( np.arange( n_classes ), get_count_imgs_per_class( y_train ), align='center' )
plt.xlabel('class')
plt.ylabel('Frequency')
plt.xlim([-1, 43])
plt.show()

# Get validation set class distribution
#Distribution very similar to that of the training set
print('*** Validation dataset')
plt.bar( np.arange( n_classes ), get_count_imgs_per_class( y_validation ), align='center' )
plt.xlabel('class')
plt.ylabel('Frequency')
plt.xlim([-1, 43])
plt.show()
# Out:
# *** Train dataset after augmentation
# 	 Total Number of images in Train dataset: 172000
# *** Validation dataset

# %% [markdown]
# ### I tried different preprocessing methods and finally decided to use the current approach

# %% [markdown]
# The data was pre-processed following the steps below:
#
# 1. the original dataset is splitted between the train set and the validation set in the ratio 4:1
#
# 2. Data augmentation.
#
# 3. Image conversion with below steps
#
#     3.1 RGB2YCrCb
#
#     3.1 cv2.equalizeHist(img_ycrcb[:,:,0])
#
#     3.3 YCrCb2RGB
#
#     3.4 prep = eqs_rgb/255. - 0.5 (normalization)

# %%
"""
def pre_processed(dataset):
    n_imgs, img_height, img_width, _ = dataset.shape
    processed_dataset = np.zeros((n_imgs, img_height, img_width, 1))
    for idx in range( len(dataset) ):
        img = dataset[idx]
        gray = cv2.cvtColor( img, cv2.COLOR_RGB2GRAY )
        #eq= cv2.equalizeHist(gray)
        #Scaling
        #eq = eq/255.0 - 0.5
        processed_dataset[idx,:,:,0] = gray/255. - 0.5
    return processed_dataset
"""
"""
def pre_processed(dataset):
    n_imgs, img_height, img_width, _ = dataset.shape
    #processed_dataset = np.zeros((n_imgs, img_height, img_width, 1))
    images = np.array(dataset, copy=True)  
    imgs = np.array([cv2.cvtColor(img, cv2.COLOR_RGB2YCrCb) for img in images])
    eqs = np.array([cv2.equalizeHist(img_ycrcb[:,:,0]) for img_ycrcb in imgs])
    eqs = eqs.reshape(-1,img_height, img_width, 1)
    eqs = eqs/255. - 0.5
    return eqs
"""
"""
# model 05
def pre_processed(dataset):
    n_imgs, img_height, img_width, img_channel = dataset.shape
    #processed_dataset = np.zeros((n_imgs, img_height, img_width, 1))
    images = np.array(dataset, copy=True)  
    imgs = np.array([cv2.cvtColor(img, cv2.COLOR_RGB2YCrCb) for img in images])
    eqs = np.array([np.dstack((cv2.equalizeHist(img_ycrcb[:,:,0]),img_ycrcb[:,:,1],img_ycrcb[:,:,2]))  for img_ycrcb in imgs])
    eqs = np.array(eqs)
    #     imgs = np.array([cv2.cvtColor(img, cv2.COLOR_YCrCb2RGB) for img in images])
    prep = eqs.reshape(-1,img_height, img_width, img_channel)
    prep = eqs/255. - 0.5
    return prep
"""
def pre_processed(dataset):
    n_imgs, img_height, img_width, img_channel = dataset.shape
    print(dataset.shape)
    
    images = np.array(dataset, copy=True)  
    imgs = np.array([cv2.cvtColor(img, cv2.COLOR_RGB2YCrCb) for img in images])
    print("converted to YCrCb")
    eqs = np.array([np.dstack((cv2.equalizeHist(img_ycrcb[:,:,0]),img_ycrcb[:,:,1],img_ycrcb[:,:,2]))  for img_ycrcb in imgs])
    eqs_c = np.array([cv2.cvtColor(img, cv2.COLOR_YCrCb2RGB) for img in eqs])
    print("converted to RGB")
    eqs_rgb = np.array(eqs_c)
    #     imgs = np.array([cv2.cvtColor(img, cv2.COLOR_YCrCb2RGB) for img in images])
    prep = eqs_rgb.reshape(-1,img_height, img_width, img_channel)
    prep = eqs_rgb/255. - 0.5
    print("reshaped and normalized")
    return prep

# %% [markdown]
# ### How data was used in training
#
# 1. the original dataset is splitted between the train set and the validation set in the ratio 4:1. The provided test set is not altered.
# Note that the train/validation data is split before the data augmentation step. It is important that the validation set is not "contaminated" by synthetic images, i.e images generated from the data augmentation.
#
# 2. Data augmentation.
# I perform data augmentation to increase the training set, but also to adjust the class distribution.
# As mentionned earlier, the class distribution in the original dataset is not uniform. Because the test set might have a different class distribution than the train set, we want the model to be trained on a uniform set of data where all classes are represented equally. When trained on a skewed dataset, the model might become bias towards the classes with the highest count. After data augmentation, all the classes have same count of samples: 4000 images per class. The total number of images after data augmentation is 172000 images, and corresponds to 6X data augmentation.
#
# The data augmentation is performed by randomly selecting images from the original dataset and then performing affine transformation:
#
# * rotation in the range [-10, 10] deg
# I limited the angle of rotation to that 'narrow' range because the meaning of some traffic signs (like the traffic signs with arrows) can changed if the angle of rotation is too large: i.e those rotated signs could fall in another classes.
# * translation along the horizontal/vertical axis: range [-3, 3] px
#
# * scaling along the horizontal/vertical axis [0.8, 1.2]

# %% [markdown]
# ----
#
# ## Step 2: Design and Test a Model Architecture
#
# Design and implement a deep learning model that learns to recognize traffic signs. Train and test your model on the [German Traffic Sign Dataset](http://benchmark.ini.rub.de/?section=gtsrb&subsection=dataset).
#
# There are various aspects to consider when thinking about this problem:
#
# - Neural network architecture
# - Play around preprocessing techniques (normalization, rgb to grayscale, etc)
# - Number of examples per label (some have more than others).
# - Generate fake data.
#
# Here is an example of a [published baseline model on this problem](http://yann.lecun.com/exdb/publis/pdf/sermanet-ijcnn-11.pdf). It's not required to be familiar with the approach used in the paper but, it's good practice to try to read papers like these.
#
# **NOTE:** The LeNet-5 implementation shown in the [classroom](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) at the end of the CNN lesson is a solid starting point. You'll have to change the number of classes and possibly the preprocessing, but aside from that it's plug and play!

# %%
# Variables Initialization function and Operations

def weight_variable(shape, mean, stddev, name, seed=SEED):
    init = tf.truncated_normal(shape, mean=mean, stddev=stddev, seed = SEED)
    return tf.Variable(init, name=name)
 

def bias_variable(shape, init_value, name):
    init = tf.constant(init_value, shape=shape)
    return tf.Variable(init, name=name)


def conv2d(x, W, strides, padding, name):
    return tf.nn.conv2d(x, W, strides=strides, padding=padding, name=name)


def max_2x2_pool(x, padding, name):
    return tf.nn.max_pool(x, ksize=[1,2,2,1], strides=[1,2,2,1], padding=padding, name=name)

# %%
# Weights and biases
# Parameters

IMG_DEPTH = 3
mu = 0
sigma = 0.05
bias_init = 0.02 
sigma2 = 0.05
bias_init2 = 0.02 
# sigma = max(0.02, 1/(Nin+Nout/2))

deep_conv1 = 32
deep_conv2 = 64
deep_conv3 = 128
deep_conv4 = 256
deep_conv5 = 512
flat = 2048
fcn1 = 512
fcn2 = 128

weights ={  
    'W_conv1': weight_variable([3, 3, IMG_DEPTH, deep_conv1], mean=mu, stddev=sigma, name='W_conv1'),
    'W_conv2': weight_variable([3, 3, deep_conv1, deep_conv2], mean=mu, stddev=sigma, name='W_conv2'),
    'W_conv3': weight_variable([4, 4, deep_conv2, deep_conv3], mean=mu, stddev=sigma, name='W_conv3'),
    'W_conv4': weight_variable([3, 3, deep_conv3, deep_conv4], mean=mu, stddev=sigma, name='W_conv4'),
    'W_conv5': weight_variable([3, 3, deep_conv4, deep_conv5], mean=mu, stddev=sigma, name='W_conv5'),
    'W_fc1': weight_variable([flat, fcn1], mean=mu, stddev=sigma2, name='W_fc1'),
    'W_fc2': weight_variable([fcn1, fcn2], mean=mu, stddev=sigma2, name='W_fc2'),
    'W_fc3': weight_variable([fcn2, 43], mean=mu, stddev=sigma2, name='W_fc3'),
}

biases = {
    'b_conv1': bias_variable(shape=[deep_conv1], init_value=bias_init, name='b_conv1'),
    'b_conv2': bias_variable(shape=[deep_conv2], init_value=bias_init, name='b_conv2'),
    'b_conv3': bias_variable(shape=[deep_conv3], init_value=bias_init, name='b_conv3'),
    'b_conv4': bias_variable(shape=[deep_conv4], init_value=bias_init, name='b_conv4'),
    'b_conv5': bias_variable(shape=[deep_conv5], init_value=bias_init, name='b_conv5'),
    'b_fc1': bias_variable([fcn1], init_value=bias_init2, name='b_fc1'),
    'b_fc2': bias_variable([fcn2], init_value=bias_init2, name='b_fc2'),
    'b_fc3': bias_variable([43], init_value=bias_init2, name='b_fc3'),
}

# %%
# Traffic Sign Model

def traffic_model(x, keep_prob,  k_p_conv, weights, biases):    
    '''
    ConvNet model for Traffic Sign Classifier
    x - input images is a tensor of shape (n_imgs, img_height, img_width, img_depth)
    keep_prob - hyper-parameter of the dropout operation
    weights - dictionary of the weights for convolutional layers and fully connected layers
    biases - dictionary of the biases for convolutional layers and fully connected layers
    '''
    
    # Convolutional block 1
    conv1 = conv2d(x, weights['W_conv1'], strides=[1,1,1,1], padding='VALID', name='conv1_op')
    conv1_act = tf.nn.relu(conv1 + biases['b_conv1'], name='conv1_act')
    conv1_drop = tf.nn.dropout(conv1_act, keep_prob=k_p_conv, name='conv1_drop')
    conv2 = conv2d(conv1_drop, weights['W_conv2'], strides=[1,1,1,1], padding='SAME', name='conv2_op')
    conv2_act = tf.nn.relu(conv2 + biases['b_conv2'], name='conv2_act')
    conv2_pool = max_2x2_pool(conv2_act, padding='VALID', name='conv2_pool')
    pool2_drop = tf.nn.dropout(conv2_pool, keep_prob=k_p_conv, name='conv2_drop')
    
    # Convolution block 2
    conv3 = conv2d(pool2_drop, weights['W_conv3'], strides=[1,1,1,1], padding='VALID', name='conv3_op')
    conv3_act = tf.nn.relu(conv3 + biases['b_conv3'], name='conv3_act')
    conv3_drop = tf.nn.dropout(conv3_act, keep_prob=k_p_conv, name='conv3_drop')
    conv4 = conv2d(conv3_drop, weights['W_conv4'], strides=[1,1,1,1], padding='SAME', name='conv4_op')
    conv4_act = tf.nn.relu(conv4 + biases['b_conv4'], name='conv4_act')
    conv4_pool = max_2x2_pool(conv4_act, padding='VALID', name='conv4_pool')
    conv4_drop = tf.nn.dropout(conv4_pool, keep_prob, name='conv4_drop')
    
    conv5 = conv2d(conv4_drop, weights['W_conv5'], strides=[1,1,1,1], padding='VALID', name='conv5_op')
    conv5_act = tf.nn.relu(conv5 + biases['b_conv5'], name='conv5_act')
    conv5_pool = max_2x2_pool(conv5_act, padding='VALID', name='conv5_pool')
    conv5_drop = tf.nn.dropout(conv5_pool, keep_prob, name='conv5_drop')
    
    # Fully connected layers
    fc0 = flatten(conv5_drop)
    fc1 = tf.nn.relu( tf.matmul( fc0, weights['W_fc1'] ) + biases['b_fc1'], name='fc1' )
    fc1_drop = tf.nn.dropout(fc1, keep_prob, name='fc1_drop')
    fc2 = tf.nn.relu( tf.matmul( fc1_drop, weights['W_fc2'] ) + biases['b_fc2'], name='fc2' )
    fc2_drop = tf.nn.dropout(fc2, keep_prob, name='fc2_drop')
    logits = tf.add(tf.matmul(fc2_drop, weights['W_fc3']),biases['b_fc3'], name='logits')  
    
    return [weights, logits]

# %% [markdown]
# ### The Deep Neural Network architecture
#
# _What does your final architecture look like? (Type of model, layers, sizes, connectivity, etc.)  For reference on how to build a deep neural network using TensorFlow, see [Deep Neural Network in TensorFlow
# ](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/b516a270-8600-4f93-a0a3-20dfeabe5da6/concepts/83a3a2a2-a9bd-4b7b-95b0-eb924ab14432) from the classroom._

# %% [markdown]
# My final model architecture is a ConvNet that is composed of 2 parts :
#
# * 3 convolutional "blocks", where each blocks are made of 2 convolutional operations back to back. Each block ends with a max pooling operation.
#
# * a block of fully connected layers feeding the 43 units softmax
#
# The non-linear function is ReLU (it prevents gradient vanishing in particular for Deep Networks)
#
#
#
# * input images (32x32x3)
#
#
# * **Convolutional layer 1** ===> output=(30x30x32)
#
#  + 32 kernels of size (3x3), 'VALID' padding and stride 1
#
# * ReLU
#
# * **Convolutional layer 2** ===> output=(30x30x64)
#
#  + 64 kernels of size (3x3), 'SAME' padding and stride 1
#
# * ReLU
#
# * Max pooling  ===> output=(15x15x64)
#
#  + 64 kernel (2x2) with stride 2 and 'SAME' padding
#
#
# * **Convolutional layer 3** ===> output=(12x12x128)
#
#  + 128 kernels of size (4x4), 'VALID' padding and stride 1
#
# * ReLU
#
#
# * **Convolutional layer 4** ===> output=(12x12x256)
#
#  + 256 kernels of size (3x3), 'SAME' padding and stride 1
#
# * ReLU
#
# * Max pooling ===> output=(6x6x256)
#
#  + (2x2) with stride 2 and 'SAME' padding
#
# * **Convolutional layer 5** ===> output=(4x4x512)
#
#  + 512 kernels of size (3x3), 'VALID' padding and stride 1
#
# * ReLU
#
# * Max pooling ===> output=(2x2x512)
#
#  + (2x2) with stride 2 and 'SAME' padding
#
# * Flatten ===> output: 2048
#
#
# * **Fully connected layer 1** ==> output: 512 units
#
# * ReLU
#
# * Dropout (keep rate of 0.5)
#
#
# * **Fully connected layer 2** ==> output: 128 units
#
# * ReLU
#
# * Dropout (keep rate of 0.5)
#
#
# * **softmax**  ==> output: 43 units

# %%
### Train your model here.
### Feel free to use as many code cells as needed.

x = tf.placeholder(tf.float32, ( None, IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH ), name='x' )
y = tf.placeholder( tf.int32, ( None ), name='y')
keep_prob = tf.placeholder( tf.float32, name='keep_prob')
k_p_conv = tf.placeholder( tf.float32, name='k_p_conv')
one_hot_y = tf.one_hot(y, n_classes )
rate = tf.placeholder( tf.float32, name='rate')

# %%
weights, logits = traffic_model(x, keep_prob,  k_p_conv, weights, biases)
softmax_operation = tf.nn.softmax(logits)
cross_entropy = tf.nn.softmax_cross_entropy_with_logits( logits=logits, labels=one_hot_y )
beta = 0.01
loss_reg = beta * (tf.nn.l2_loss(weights['W_fc1']) + tf.nn.l2_loss(weights['W_fc2']) + tf.nn.l2_loss(weights['W_fc3']) )
loss = tf.reduce_mean( cross_entropy ) + loss_reg

optimizer = tf.train.AdamOptimizer( learning_rate = rate )
training_operation = optimizer.minimize( loss )

# %%
correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(one_hot_y, 1))
accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

def evaluate(X_data, y_data):
    num_examples = len(X_data)
    total_accuracy = 0
    sess = tf.get_default_session()
    total_l = 0
    for offset in range(0, num_examples, BATCH_SIZE):
        batch_x, batch_y = X_data[offset:offset+BATCH_SIZE], y_data[offset:offset+BATCH_SIZE]
        accuracy, l = sess.run([accuracy_operation, loss], \
                               feed_dict={x: batch_x, y: batch_y,  k_p_conv:1, keep_prob: 1})
        total_accuracy += (accuracy * len(batch_x))
        total_l += (l * len(batch_x) )
    return [total_accuracy / num_examples, total_l/num_examples]

# %%
import datetime

EPOCHS = 100
BATCH_SIZE = 256
model_nbr = '200'
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    num_examples = len(X_train)
    print("Training... \n")
    summary_train = []
    l_rate = 0.001
    keep_rate = 0.5
    kp_conv = 0.6
    

    print('Pre-processing X_train....')
    X_train_prep = pre_processed(X_train).reshape(-1, IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH)
    X_validation_prep = pre_processed(X_validation).reshape(-1, IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH)
    X_valid_prep = pre_processed(X_valid).reshape(-1, IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH)    
    print('X_train pre-processed datatset size: {} | data type: {}'.format(X_train_prep.shape, X_train_prep.dtype))
    print('End Pre-processing X_train.... \n')    
    
    
    t_start = datetime.datetime.now()    
    for i in range(EPOCHS):
        t1 = datetime.datetime.now()
        #scheme to decrease learning rate by step
        if i >= 20:
            l_rate = 0.0001
        if i>= 50:
            l_rate = 0.00005

        
        X_train_prep, y_train = shuffle(X_train_prep, y_train)
        

        for offset in range(0, num_examples, BATCH_SIZE):
            end = offset + BATCH_SIZE
            batch_x, batch_y =  X_train_prep[offset:end], y_train[offset:end]

            sess.run(training_operation, feed_dict={x: batch_x, y: batch_y, keep_prob: keep_rate, \
                                                k_p_conv: kp_conv, rate: l_rate})

        train_accuracy, train_loss = evaluate(X_train_prep, y_train)
        validation_accuracy, validation_loss = evaluate(X_validation_prep, y_validation)
        valid_accuracy, valid_loss = evaluate(X_valid_prep, y_valid)
        
        t2 = datetime.datetime.now()
        
        print("EPOCH {} ...".format(i+1))
        print("Computation time: " + str(t2-t1))
        print("Train accuracy: {:.4f} | Validation Accuracy = {:.4f} | Valid Accuracy = {:.4f}".format(train_accuracy, validation_accuracy, valid_accuracy))
        print("Train loss: {:.5f} | Validation loss = {:.5f} | Valid loss = {:.5f} \n".format(train_loss, validation_loss, valid_loss))
        summary_train.append([i+1, train_accuracy, validation_accuracy, valid_accuracy, train_loss, validation_loss, valid_loss])

    t_end = datetime.datetime.now() 
    print("Whole computation time: " + str(t_end-t_start))
    summary_train = np.array(summary_train)
    np.save('summary_train_'+model_nbr+'.npy', summary_train) 
    try:
        saver
    except NameError:
        saver = tf.train.Saver()
    saver.save(sess, '.\\traffic_model'+model_nbr)
    print("Model saved")

    
### Plot loss
    fig, ax = plt.subplots(1, 3, figsize=(15,3))
    plt.subplots_adjust(wspace = .2)
    # set font size tick parameters, x/y labels
    for i in range( len(ax) ):
        ax[i].tick_params(axis='x', labelsize=12)
        ax[i].tick_params(axis='y', labelsize=12)
        ax[i].xaxis.label.set_fontsize(12)
        ax[i].yaxis.label.set_fontsize(12)
    marker_size = 8
    ax[0].plot(summary_train[:,0], summary_train[:,1], 'b-o', markersize=marker_size, label='Train')
    ax[0].plot(summary_train[:,0], summary_train[:,2], 'r-o', markersize=marker_size, label='Validation')
    ax[0].plot(summary_train[:,0], summary_train[:,3], 'g-o', markersize=marker_size, label='Valid')    
    ax[0].set_xlabel('EPOCH')
    ax[0].set_ylabel('ACCURACY')
    
    ax[1].semilogy(summary_train[:,0], summary_train[:,4], 'b-o', markersize=marker_size, label='Train')
    ax[1].semilogy(summary_train[:,0], summary_train[:,5], 'r-o', markersize=marker_size, label='Validation')
    ax[1].semilogy(summary_train[:,0], summary_train[:,6], 'g-o', markersize=marker_size, label='Valid')    
    ax[1].set_xlabel('EPOCH')
    ax[1].set_ylabel('LOSS')

    ax[2].semilogy(summary_train[:,0], summary_train[:,4]/summary_train[:,5], 'k-o', markersize=marker_size, label='Train1')
    ax[2].semilogy(summary_train[:,0], summary_train[:,4]/summary_train[:,6], 'g-o', markersize=marker_size, label='Train2')
    ax[2].set_xlabel('EPOCH')
    ax[2].set_ylabel('LOSS RATIO TRAIN/VALID')
    
    plt.show()
# Out:
# Training...
#
# Pre-processing X_train....
# (172000, 32, 32, 3)
# converted to YCrCb
# converted to RGB
# reshaped and normalized
# (6960, 32, 32, 3)
# converted to YCrCb
# converted to RGB
# reshaped and normalized
# (4410, 32, 32, 3)
# converted to YCrCb
# converted to RGB
# reshaped and normalized
# X_train pre-processed datatset size: (172000, 32, 32, 3) | data type: float64
# End Pre-processing X_train....
#
# EPOCH 1 ...
# Computation time: 0:01:27.247489
# Train accuracy: 0.9052 | Validation Accuracy = 0.4437 | Valid Accuracy = 0.4066
# Train loss: 0.90559 | Validation loss = 2.39071 | Valid loss = 2.56219
#
# EPOCH 2 ...
# Computation time: 0:00:44.032202
# Train accuracy: 0.9421 | Validation Accuracy = 0.6323 | Valid Accuracy = 0.5794
# Train loss: 0.63127 | Validation loss = 1.57019 | Valid loss = 1.75199
#
# EPOCH 3 ...
# Computation time: 0:00:44.448091
# Train accuracy: 0.9725 | Validation Accuracy = 0.8175 | Valid Accuracy = 0.7766
# Train loss: 0.51714 | Validation loss = 1.03973 | Valid loss = 1.21046
#
# EPOCH 4 ...
# Computation time: 0:00:44.852128
# Train accuracy: 0.9825 | Validation Accuracy = 0.8819 | Valid Accuracy = 0.8322
# Train loss: 0.45568 | Validation loss = 0.79909 | Valid loss = 0.97583
#
# EPOCH 5 ...
# Computation time: 0:00:44.626976
# Train accuracy: 0.9880 | Validation Accuracy = 0.9167 | Valid Accuracy = 0.8884
# Train loss: 0.41347 | Validation loss = 0.64497 | Valid loss = 0.76667
#
# EPOCH 6 ...
# Computation time: 0:00:44.652436
# Train accuracy: 0.9931 | Validation Accuracy = 0.9516 | Valid Accuracy = 0.9109
# Train loss: 0.38852 | Validation loss = 0.53829 | Valid loss = 0.67625
#
# EPOCH 7 ...
# Computation time: 0:00:44.371031
# Train accuracy: 0.9945 | Validation Accuracy = 0.9616 | Valid Accuracy = 0.9234
# Train loss: 0.35628 | Validation loss = 0.47685 | Valid loss = 0.59864
#
# EPOCH 8 ...
# Computation time: 0:00:44.553434
# Train accuracy: 0.9954 | Validation Accuracy = 0.9661 | Valid Accuracy = 0.9447
# Train loss: 0.35233 | Validation loss = 0.45468 | Valid loss = 0.52664
#
# EPOCH 9 ...
# Computation time: 0:00:44.266449
# Train accuracy: 0.9967 | Validation Accuracy = 0.9741 | Valid Accuracy = 0.9476
# Train loss: 0.35744 | Validation loss = 0.43838 | Valid loss = 0.53952
#
# EPOCH 10 ...
# Computation time: 0:00:44.756282
# Train accuracy: 0.9976 | Validation Accuracy = 0.9763 | Valid Accuracy = 0.9381
# Train loss: 0.30876 | Validation loss = 0.37987 | Valid loss = 0.52229
#
# EPOCH 11 ...
# Computation time: 0:00:44.536063
# Train accuracy: 0.9986 | Validation Accuracy = 0.9852 | Valid Accuracy = 0.9567
# Train loss: 0.32860 | Validation loss = 0.37608 | Valid loss = 0.46691
#
# EPOCH 12 ...
# Computation time: 0:00:44.555447
# Train accuracy: 0.9986 | Validation Accuracy = 0.9859 | Valid Accuracy = 0.9630
# Train loss: 0.32279 | Validation loss = 0.36941 | Valid loss = 0.44640
#
# EPOCH 13 ...
# Computation time: 0:00:44.312805
# Train accuracy: 0.9990 | Validation Accuracy = 0.9891 | Valid Accuracy = 0.9735
# Train loss: 0.31180 | Validation loss = 0.35047 | Valid loss = 0.41326
#
# EPOCH 14 ...
# Computation time: 0:00:44.598077
# Train accuracy: 0.9989 | Validation Accuracy = 0.9904 | Valid Accuracy = 0.9703
# Train loss: 0.30389 | Validation loss = 0.34179 | Valid loss = 0.42887
#
# EPOCH 15 ...
# Computation time: 0:00:44.406764
# Train accuracy: 0.9994 | Validation Accuracy = 0.9931 | Valid Accuracy = 0.9812
# Train loss: 0.28661 | Validation loss = 0.31512 | Valid loss = 0.36446
#
# EPOCH 16 ...
# Computation time: 0:00:45.007899
# Train accuracy: 0.9992 | Validation Accuracy = 0.9912 | Valid Accuracy = 0.9810
# Train loss: 0.33667 | Validation loss = 0.37310 | Valid loss = 0.40944
#
# EPOCH 17 ...
# Computation time: 0:00:44.648068
# Train accuracy: 0.9994 | Validation Accuracy = 0.9925 | Valid Accuracy = 0.9830
# Train loss: 0.27448 | Validation loss = 0.30464 | Valid loss = 0.34275
#
# EPOCH 18 ...
# Computation time: 0:00:44.459862
# Train accuracy: 0.9995 | Validation Accuracy = 0.9944 | Valid Accuracy = 0.9887
# Train loss: 0.28834 | Validation loss = 0.31123 | Valid loss = 0.33352
#
# EPOCH 19 ...
# Computation time: 0:00:44.685313
# Train accuracy: 0.9996 | Validation Accuracy = 0.9943 | Valid Accuracy = 0.9868
# Train loss: 0.30143 | Validation loss = 0.32467 | Valid loss = 0.35570
#
# EPOCH 20 ...
# Computation time: 0:00:44.326952
# Train accuracy: 0.9996 | Validation Accuracy = 0.9950 | Valid Accuracy = 0.9844
# Train loss: 0.32643 | Validation loss = 0.34865 | Valid loss = 0.40202
#
# EPOCH 21 ...
# Computation time: 0:00:44.521091
# Train accuracy: 0.9998 | Validation Accuracy = 0.9960 | Valid Accuracy = 0.9871
# Train loss: 0.18839 | Validation loss = 0.20474 | Valid loss = 0.25464
#
# EPOCH 22 ...
# Computation time: 0:00:44.427227
# Train accuracy: 0.9998 | Validation Accuracy = 0.9961 | Valid Accuracy = 0.9864
# Train loss: 0.11591 | Validation loss = 0.13044 | Valid loss = 0.17403
#
# EPOCH 23 ...
# Computation time: 0:00:44.433947
# Train accuracy: 0.9998 | Validation Accuracy = 0.9964 | Valid Accuracy = 0.9871
# Train loss: 0.07789 | Validation loss = 0.09049 | Valid loss = 0.13368
#
# EPOCH 24 ...
# Computation time: 0:00:44.574979
# Train accuracy: 0.9998 | Validation Accuracy = 0.9957 | Valid Accuracy = 0.9848
# Train loss: 0.05887 | Validation loss = 0.07273 | Valid loss = 0.12002
#
# EPOCH 25 ...
# Computation time: 0:00:44.499952
# Train accuracy: 0.9998 | Validation Accuracy = 0.9960 | Valid Accuracy = 0.9844
# Train loss: 0.04956 | Validation loss = 0.06371 | Valid loss = 0.10918
#
# EPOCH 26 ...
# Computation time: 0:00:44.344285
# Train accuracy: 0.9999 | Validation Accuracy = 0.9968 | Valid Accuracy = 0.9868
# Train loss: 0.04415 | Validation loss = 0.05668 | Valid loss = 0.09922
#
# EPOCH 27 ...
# Computation time: 0:00:44.168253
# Train accuracy: 0.9999 | Validation Accuracy = 0.9968 | Valid Accuracy = 0.9878
# Train loss: 0.04265 | Validation loss = 0.05608 | Valid loss = 0.09544
#
# EPOCH 28 ...
# Computation time: 0:00:44.101339
# Train accuracy: 0.9999 | Validation Accuracy = 0.9963 | Valid Accuracy = 0.9862
# Train loss: 0.03942 | Validation loss = 0.05341 | Valid loss = 0.09075
#
# EPOCH 29 ...
# Computation time: 0:00:44.271588
# Train accuracy: 0.9999 | Validation Accuracy = 0.9973 | Valid Accuracy = 0.9873
# Train loss: 0.03822 | Validation loss = 0.05096 | Valid loss = 0.08931
#
# EPOCH 30 ...
# Computation time: 0:00:44.758282
# Train accuracy: 0.9999 | Validation Accuracy = 0.9967 | Valid Accuracy = 0.9884
# Train loss: 0.03800 | Validation loss = 0.05011 | Valid loss = 0.08012
#
# EPOCH 31 ...
# Computation time: 0:00:44.338045
# Train accuracy: 0.9999 | Validation Accuracy = 0.9971 | Valid Accuracy = 0.9884
# Train loss: 0.03679 | Validation loss = 0.04768 | Valid loss = 0.08619
#
# EPOCH 32 ...
# Computation time: 0:00:45.019229
# Train accuracy: 0.9999 | Validation Accuracy = 0.9968 | Valid Accuracy = 0.9859
# Train loss: 0.03578 | Validation loss = 0.04679 | Valid loss = 0.08822
#
# EPOCH 33 ...
# Computation time: 0:00:44.891853
# Train accuracy: 0.9999 | Validation Accuracy = 0.9971 | Valid Accuracy = 0.9857
# Train loss: 0.03559 | Validation loss = 0.04635 | Valid loss = 0.09016
#
# EPOCH 34 ...
# Computation time: 0:00:44.523653
# Train accuracy: 0.9999 | Validation Accuracy = 0.9978 | Valid Accuracy = 0.9878
# Train loss: 0.03472 | Validation loss = 0.04411 | Valid loss = 0.08008
#
# EPOCH 35 ...
# Computation time: 0:00:44.472426
# Train accuracy: 0.9999 | Validation Accuracy = 0.9964 | Valid Accuracy = 0.9866
# Train loss: 0.03491 | Validation loss = 0.04759 | Valid loss = 0.08589
#
# EPOCH 36 ...
# Computation time: 0:00:44.408873
# Train accuracy: 0.9999 | Validation Accuracy = 0.9971 | Valid Accuracy = 0.9823
# Train loss: 0.03517 | Validation loss = 0.04815 | Valid loss = 0.10515
#
# EPOCH 37 ...
# Computation time: 0:00:44.422153
# Train accuracy: 0.9999 | Validation Accuracy = 0.9976 | Valid Accuracy = 0.9880
# Train loss: 0.03352 | Validation loss = 0.04364 | Valid loss = 0.08462
#
# EPOCH 38 ...
# Computation time: 0:00:44.607542
# Train accuracy: 0.9999 | Validation Accuracy = 0.9961 | Valid Accuracy = 0.9873
# Train loss: 0.03291 | Validation loss = 0.04533 | Valid loss = 0.08016
#
# EPOCH 39 ...
# Computation time: 0:00:44.640454
# Train accuracy: 0.9999 | Validation Accuracy = 0.9967 | Valid Accuracy = 0.9855
# Train loss: 0.03349 | Validation loss = 0.04425 | Valid loss = 0.08965
#
# EPOCH 40 ...
# Computation time: 0:00:44.380619
# Train accuracy: 0.9999 | Validation Accuracy = 0.9976 | Valid Accuracy = 0.9857
# Train loss: 0.03249 | Validation loss = 0.04256 | Valid loss = 0.08655
#
# EPOCH 41 ...
# Computation time: 0:00:44.959047
# Train accuracy: 0.9999 | Validation Accuracy = 0.9968 | Valid Accuracy = 0.9844
# Train loss: 0.03281 | Validation loss = 0.04355 | Valid loss = 0.08983
#
# EPOCH 42 ...
# Computation time: 0:00:44.764507
# Train accuracy: 0.9999 | Validation Accuracy = 0.9970 | Valid Accuracy = 0.9882
# Train loss: 0.03288 | Validation loss = 0.04272 | Valid loss = 0.08641
#
# EPOCH 43 ...
# Computation time: 0:00:44.548570
# Train accuracy: 0.9999 | Validation Accuracy = 0.9966 | Valid Accuracy = 0.9864
# Train loss: 0.03228 | Validation loss = 0.04270 | Valid loss = 0.08892
#
# EPOCH 44 ...
# Computation time: 0:00:44.659457
# Train accuracy: 0.9999 | Validation Accuracy = 0.9976 | Valid Accuracy = 0.9880
# Train loss: 0.03274 | Validation loss = 0.04321 | Valid loss = 0.07703
#
# EPOCH 45 ...
# Computation time: 0:00:44.560312
# Train accuracy: 0.9999 | Validation Accuracy = 0.9983 | Valid Accuracy = 0.9873
# Train loss: 0.03153 | Validation loss = 0.04024 | Valid loss = 0.08063
#
# EPOCH 46 ...
# Computation time: 0:00:44.463909
# Train accuracy: 0.9999 | Validation Accuracy = 0.9974 | Valid Accuracy = 0.9882
# Train loss: 0.03283 | Validation loss = 0.04329 | Valid loss = 0.08664
#
# EPOCH 47 ...
# Computation time: 0:00:44.601930
# Train accuracy: 0.9999 | Validation Accuracy = 0.9978 | Valid Accuracy = 0.9868
# Train loss: 0.03251 | Validation loss = 0.04093 | Valid loss = 0.08135
#
# EPOCH 48 ...
# Computation time: 0:00:44.640298
# Train accuracy: 0.9999 | Validation Accuracy = 0.9973 | Valid Accuracy = 0.9873
# Train loss: 0.03164 | Validation loss = 0.04279 | Valid loss = 0.08650
#
# EPOCH 49 ...
# Computation time: 0:00:44.634115
# Train accuracy: 0.9999 | Validation Accuracy = 0.9974 | Valid Accuracy = 0.9844
# Train loss: 0.03114 | Validation loss = 0.03943 | Valid loss = 0.09197
#
# EPOCH 50 ...
# Computation time: 0:00:44.692350
# Train accuracy: 1.0000 | Validation Accuracy = 0.9976 | Valid Accuracy = 0.9875
# Train loss: 0.03172 | Validation loss = 0.04129 | Valid loss = 0.08745
#
# EPOCH 51 ...
# Computation time: 0:00:44.778096
# Train accuracy: 0.9999 | Validation Accuracy = 0.9978 | Valid Accuracy = 0.9878
# Train loss: 0.02746 | Validation loss = 0.03539 | Valid loss = 0.08401
#
# EPOCH 52 ...
# Computation time: 0:00:44.968274
# Train accuracy: 0.9999 | Validation Accuracy = 0.9974 | Valid Accuracy = 0.9896
# Train loss: 0.02478 | Validation loss = 0.03394 | Valid loss = 0.06819
#
# EPOCH 53 ...
# Computation time: 0:00:43.934238
# Train accuracy: 0.9999 | Validation Accuracy = 0.9976 | Valid Accuracy = 0.9880
# Train loss: 0.02333 | Validation loss = 0.03220 | Valid loss = 0.07492
#
# EPOCH 54 ...
# Computation time: 0:00:43.594593
# Train accuracy: 1.0000 | Validation Accuracy = 0.9980 | Valid Accuracy = 0.9914
# Train loss: 0.02246 | Validation loss = 0.03052 | Valid loss = 0.05876
#
# EPOCH 55 ...
# Computation time: 0:00:43.980686
# Train accuracy: 0.9999 | Validation Accuracy = 0.9980 | Valid Accuracy = 0.9889
# Train loss: 0.02213 | Validation loss = 0.02955 | Valid loss = 0.07012
#
# EPOCH 56 ...
# Computation time: 0:00:43.864089
# Train accuracy: 0.9999 | Validation Accuracy = 0.9980 | Valid Accuracy = 0.9909
# Train loss: 0.02162 | Validation loss = 0.02930 | Valid loss = 0.05613
#
# EPOCH 57 ...
# Computation time: 0:00:44.327280
# Train accuracy: 0.9999 | Validation Accuracy = 0.9984 | Valid Accuracy = 0.9884
# Train loss: 0.02144 | Validation loss = 0.02870 | Valid loss = 0.06797
#
# EPOCH 58 ...
# Computation time: 0:00:43.884023
# Train accuracy: 1.0000 | Validation Accuracy = 0.9986 | Valid Accuracy = 0.9868
# Train loss: 0.02137 | Validation loss = 0.02889 | Valid loss = 0.07162
#
# EPOCH 59 ...
# Computation time: 0:00:43.830229
# Train accuracy: 0.9999 | Validation Accuracy = 0.9980 | Valid Accuracy = 0.9900
# Train loss: 0.02130 | Validation loss = 0.02835 | Valid loss = 0.06637
#
# EPOCH 60 ...
# Computation time: 0:00:43.992672
# Train accuracy: 0.9999 | Validation Accuracy = 0.9980 | Valid Accuracy = 0.9889
# Train loss: 0.02087 | Validation loss = 0.02895 | Valid loss = 0.06958
#
# EPOCH 61 ...
# Computation time: 0:00:43.847040
# Train accuracy: 0.9999 | Validation Accuracy = 0.9977 | Valid Accuracy = 0.9884
# Train loss: 0.02087 | Validation loss = 0.02928 | Valid loss = 0.06886
#
# EPOCH 62 ...
# Computation time: 0:00:44.336093
# Train accuracy: 0.9999 | Validation Accuracy = 0.9977 | Valid Accuracy = 0.9875
# Train loss: 0.02087 | Validation loss = 0.02831 | Valid loss = 0.07178
#
# EPOCH 63 ...
# Computation time: 0:00:45.130144
# Train accuracy: 0.9999 | Validation Accuracy = 0.9978 | Valid Accuracy = 0.9857
# Train loss: 0.02076 | Validation loss = 0.02916 | Valid loss = 0.07768
#
# EPOCH 64 ...
# Computation time: 0:00:44.785839
# Train accuracy: 1.0000 | Validation Accuracy = 0.9980 | Valid Accuracy = 0.9850
# Train loss: 0.02053 | Validation loss = 0.02843 | Valid loss = 0.07765
#
# EPOCH 65 ...
# Computation time: 0:00:44.296914
# Train accuracy: 0.9999 | Validation Accuracy = 0.9976 | Valid Accuracy = 0.9891
# Train loss: 0.02006 | Validation loss = 0.02946 | Valid loss = 0.06999
#
# EPOCH 66 ...
# Computation time: 0:00:44.529572
# Train accuracy: 1.0000 | Validation Accuracy = 0.9986 | Valid Accuracy = 0.9909
# Train loss: 0.02001 | Validation loss = 0.02794 | Valid loss = 0.05957
#
# EPOCH 67 ...
# Computation time: 0:00:44.381447
# Train accuracy: 1.0000 | Validation Accuracy = 0.9976 | Valid Accuracy = 0.9891
# Train loss: 0.01985 | Validation loss = 0.02786 | Valid loss = 0.06730
#
# EPOCH 68 ...
# Computation time: 0:00:43.899634
# Train accuracy: 0.9999 | Validation Accuracy = 0.9977 | Valid Accuracy = 0.9880
# Train loss: 0.01968 | Validation loss = 0.02879 | Valid loss = 0.07327
#
# EPOCH 69 ...
# Computation time: 0:00:44.342698
# Train accuracy: 0.9999 | Validation Accuracy = 0.9977 | Valid Accuracy = 0.9891
# Train loss: 0.02007 | Validation loss = 0.02853 | Valid loss = 0.06656
#
# EPOCH 70 ...
# Computation time: 0:00:44.436786
# Train accuracy: 0.9999 | Validation Accuracy = 0.9984 | Valid Accuracy = 0.9884
# Train loss: 0.01993 | Validation loss = 0.02763 | Valid loss = 0.06488
#
# EPOCH 71 ...
# Computation time: 0:00:44.343923
# Train accuracy: 0.9999 | Validation Accuracy = 0.9981 | Valid Accuracy = 0.9857
# Train loss: 0.01962 | Validation loss = 0.02711 | Valid loss = 0.07121
#
# EPOCH 72 ...
# Computation time: 0:00:43.959736
# Train accuracy: 1.0000 | Validation Accuracy = 0.9986 | Valid Accuracy = 0.9900
# Train loss: 0.02017 | Validation loss = 0.02756 | Valid loss = 0.06107
#
# EPOCH 73 ...
# Computation time: 0:00:43.734192
# Train accuracy: 1.0000 | Validation Accuracy = 0.9978 | Valid Accuracy = 0.9884
# Train loss: 0.01994 | Validation loss = 0.02691 | Valid loss = 0.06166
#
# EPOCH 74 ...
# Computation time: 0:00:44.063627
# Train accuracy: 1.0000 | Validation Accuracy = 0.9983 | Valid Accuracy = 0.9866
# Train loss: 0.01987 | Validation loss = 0.02766 | Valid loss = 0.07313
#
# EPOCH 75 ...
# Computation time: 0:00:44.568703
# Train accuracy: 1.0000 | Validation Accuracy = 0.9983 | Valid Accuracy = 0.9857
# Train loss: 0.02021 | Validation loss = 0.02784 | Valid loss = 0.07194
#
# EPOCH 76 ...
# Computation time: 0:00:43.737682
# Train accuracy: 1.0000 | Validation Accuracy = 0.9983 | Valid Accuracy = 0.9871
# Train loss: 0.02025 | Validation loss = 0.02743 | Valid loss = 0.06360
#
# EPOCH 77 ...
# Computation time: 0:00:43.702620
# Train accuracy: 1.0000 | Validation Accuracy = 0.9981 | Valid Accuracy = 0.9893
# Train loss: 0.02001 | Validation loss = 0.02802 | Valid loss = 0.06552
#
# EPOCH 78 ...
# Computation time: 0:00:43.767996
# Train accuracy: 0.9999 | Validation Accuracy = 0.9981 | Valid Accuracy = 0.9889
# Train loss: 0.01978 | Validation loss = 0.02768 | Valid loss = 0.06219
#
# EPOCH 79 ...
# Computation time: 0:00:44.000204
# Train accuracy: 1.0000 | Validation Accuracy = 0.9984 | Valid Accuracy = 0.9878
# Train loss: 0.01985 | Validation loss = 0.02664 | Valid loss = 0.06099
#
# EPOCH 80 ...
# Computation time: 0:00:43.691473
# Train accuracy: 1.0000 | Validation Accuracy = 0.9984 | Valid Accuracy = 0.9900
# Train loss: 0.01936 | Validation loss = 0.02771 | Valid loss = 0.06095
#
# EPOCH 81 ...
# Computation time: 0:00:43.861713
# Train accuracy: 1.0000 | Validation Accuracy = 0.9977 | Valid Accuracy = 0.9893
# Train loss: 0.01946 | Validation loss = 0.02748 | Valid loss = 0.06291
#
# EPOCH 82 ...
# Computation time: 0:00:43.784382
# Train accuracy: 1.0000 | Validation Accuracy = 0.9983 | Valid Accuracy = 0.9880
# Train loss: 0.01945 | Validation loss = 0.02723 | Valid loss = 0.06742
#
# EPOCH 83 ...
# Computation time: 0:00:44.079832
# Train accuracy: 1.0000 | Validation Accuracy = 0.9984 | Valid Accuracy = 0.9902
# Train loss: 0.01922 | Validation loss = 0.02728 | Valid loss = 0.05636
#
# EPOCH 84 ...
# Computation time: 0:00:43.953160
# Train accuracy: 1.0000 | Validation Accuracy = 0.9987 | Valid Accuracy = 0.9887
# Train loss: 0.01903 | Validation loss = 0.02574 | Valid loss = 0.06122
#
# EPOCH 85 ...
# Computation time: 0:00:43.734354
# Train accuracy: 1.0000 | Validation Accuracy = 0.9989 | Valid Accuracy = 0.9900
# Train loss: 0.01929 | Validation loss = 0.02657 | Valid loss = 0.05653
#
# EPOCH 86 ...
# Computation time: 0:00:44.012738
# Train accuracy: 1.0000 | Validation Accuracy = 0.9983 | Valid Accuracy = 0.9864
# Train loss: 0.01928 | Validation loss = 0.02644 | Valid loss = 0.07149
#
# EPOCH 87 ...
# Computation time: 0:00:44.111114
# Train accuracy: 0.9999 | Validation Accuracy = 0.9976 | Valid Accuracy = 0.9868
# Train loss: 0.01924 | Validation loss = 0.02752 | Valid loss = 0.07358
#
# EPOCH 88 ...
# Computation time: 0:00:43.727532
# Train accuracy: 1.0000 | Validation Accuracy = 0.9980 | Valid Accuracy = 0.9882
# Train loss: 0.01921 | Validation loss = 0.02608 | Valid loss = 0.07055
#
# EPOCH 89 ...
# Computation time: 0:00:43.621463
# Train accuracy: 1.0000 | Validation Accuracy = 0.9980 | Valid Accuracy = 0.9887
# Train loss: 0.01949 | Validation loss = 0.02714 | Valid loss = 0.06996
#
# EPOCH 90 ...
# Computation time: 0:00:43.665739
# Train accuracy: 1.0000 | Validation Accuracy = 0.9981 | Valid Accuracy = 0.9884
# Train loss: 0.01921 | Validation loss = 0.02595 | Valid loss = 0.07125
#
# EPOCH 91 ...
# Computation time: 0:00:43.918214
# Train accuracy: 1.0000 | Validation Accuracy = 0.9986 | Valid Accuracy = 0.9875
# Train loss: 0.01876 | Validation loss = 0.02552 | Valid loss = 0.06346
#
# EPOCH 92 ...
# Computation time: 0:00:43.799019
# Train accuracy: 1.0000 | Validation Accuracy = 0.9987 | Valid Accuracy = 0.9898
# Train loss: 0.01891 | Validation loss = 0.02676 | Valid loss = 0.06166
#
# EPOCH 93 ...
# Computation time: 0:00:43.697874
# Train accuracy: 1.0000 | Validation Accuracy = 0.9986 | Valid Accuracy = 0.9880
# Train loss: 0.01881 | Validation loss = 0.02662 | Valid loss = 0.06798
#
# EPOCH 94 ...
# Computation time: 0:00:43.595860
# Train accuracy: 0.9999 | Validation Accuracy = 0.9980 | Valid Accuracy = 0.9878
# Train loss: 0.01922 | Validation loss = 0.02780 | Valid loss = 0.06696
#
# EPOCH 95 ...
# Computation time: 0:00:43.806194
# Train accuracy: 1.0000 | Validation Accuracy = 0.9987 | Valid Accuracy = 0.9896
# Train loss: 0.01874 | Validation loss = 0.02559 | Valid loss = 0.06629
#
# EPOCH 96 ...
# Computation time: 0:00:43.690421
# Train accuracy: 1.0000 | Validation Accuracy = 0.9987 | Valid Accuracy = 0.9866
# Train loss: 0.01868 | Validation loss = 0.02477 | Valid loss = 0.07108
#
# EPOCH 97 ...
# Computation time: 0:00:43.726001
# Train accuracy: 1.0000 | Validation Accuracy = 0.9984 | Valid Accuracy = 0.9875
# Train loss: 0.01875 | Validation loss = 0.02581 | Valid loss = 0.07227
#
# EPOCH 98 ...
# Computation time: 0:00:43.626761
# Train accuracy: 1.0000 | Validation Accuracy = 0.9990 | Valid Accuracy = 0.9889
# Train loss: 0.01900 | Validation loss = 0.02508 | Valid loss = 0.06036
#
# EPOCH 99 ...
# Computation time: 0:00:43.866286
# Train accuracy: 1.0000 | Validation Accuracy = 0.9984 | Valid Accuracy = 0.9882
# Train loss: 0.01871 | Validation loss = 0.02530 | Valid loss = 0.06322
#
# EPOCH 100 ...
# Computation time: 0:00:43.821623
# Train accuracy: 1.0000 | Validation Accuracy = 0.9989 | Valid Accuracy = 0.9884
# Train loss: 0.01857 | Validation loss = 0.02488 | Valid loss = 0.06559
#
# Whole computation time: 1:14:30.485840
# Model saved

# %% [markdown]
# ### Model training

# %% [markdown]
#
#
#  **Answer:**
#
#
# * **Optimizer: AdamOptimizer**
#
# * **Batch size: 256 images**
# The batch size was varied from 64 to 500.
#
# * **Sigma: 0.05**
# One of the parameters that affected the most the model performance was the standard deviation of the weight initializer. The weights values are initialized using a truncated Gaussian distribution with a mean of 0 and standard deviation *sigma*. If the standard deviation is too low or too high, the model will be barely learning during training. The loss would go down very slowly or not at all, and this independently of the learning rate chosen. In fact, depending on the normalization method used, the optimum sigma value may be different.
#
# * **Learning rate: 0.001**
# I had to find the right balance between a learning rate too high where at worst the model does not learn, versus a learning rate too low where the convergence is slow. The learning rate is decreased to 0.0001 at EPOCH=20, and to 0.00005 at EPOCH=50, to  prevent the system to be stucked in a local minima. Looks effective
#
# * **EPOCHS: 100**
# I trained the model for 100 EPOCHS.
#
# * **Dropout with keep rate of 0.5**
# The best keep rate was 0.5 for the fully connected layer. When the keep rate was below 0.5, the learning was at best slow with a loss that decreases very slowly. The convolutional layers used also dropout but with a higher *keep_rate* of 0.5.
#
# * ** Pooling**
# The pooling decreases the size of the output. It also prevents overfitting as a consequence of reducing number of parameters.
#
# * ** L2 regularization**
# Because the model still shows evidence of overfitting at high EPOCH (see Figure below), the L2 norm regularizer is applied to the weights of the Dense layers.

# %% [markdown]
# ### Solution Approach

# %% [markdown]
# First, I implemented a LeNet which achieved accuracy of around 80%.
# Then I tried the Deep network like above help a lot no matter what initial parameters are set (achieving accuracy over 90%).
# But Deeper and wider networks do helps but also faced the problem of overfitting.
#
# Data augmentation is helpful but need to be balanced. (too much data make the training very slow, but didn't help to improve further from 98%)
# For tackling overfitting below methods helped,
# - Dropout with 0.5 rate is better than 0.75.
# - I also included dropout and L2-regularization. Dropout was more efficient at controlling overfitting.
# - L2 regularization
# - Learning rate decay (in 3 phases)
#
#
#
# * Train accuracy: 100%
# * Validation accuracy: 99.89%
# * Test accuracy: 98.84%
#
# The training process shows overfitting, early stopping maybe necessary.

# %% [markdown]
# ---
#
# ## Step 3: Test a Model on New Images
#
# Take several pictures of traffic signs that you find on the web or around you (at least five), and run them through your classifier on your computer to produce example results. The classifier might not recognize some local signs but it could prove interesting nonetheless.
#
# You may find `signnames.csv` useful as it contains mappings from the class id (integer) to the actual sign name.

# %% [markdown]
# ### Implementation
#
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project. Once you have completed your implementation and are satisfied with the results, be sure to thoroughly answer the questions that follow.

# %%
with tf.Session() as sess:
    
    loader = tf.train.import_meta_graph('traffic_model'+model_nbr+'.meta')
    loader.restore(sess, tf.train.latest_checkpoint('./'))
    X_test_prep = pre_processed(X_test).reshape(-1, IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH)
    test_accuracy, _ = evaluate(X_test_prep, y_test)
    
    # select 20 random images 
    # /!\ feeding the entire X_test overflows the GPU memory for softmax_op
    ls = [random.randint(0, len(y_test)) for i in range(20)]
    X_test_select = np.zeros((20, IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH))
    y_test_select = np.zeros((20,1))
    for i in range(len(ls)):
        X_test_select[i] = X_test_prep[ls[i]]
        y_test_select = y_test[ls[i]]
        
    test_pred_proba = sess.run(softmax_operation, feed_dict={x: X_test_select,  k_p_conv:1, keep_prob: 1})
    prediction_test = np.argmax(test_pred_proba, 1)
    print("Test Accuracy = {:.4f}".format(test_accuracy))
# Out:
# INFO:tensorflow:Restoring parameters from ./traffic_model200
# (12630, 32, 32, 3)
# converted to YCrCb
# converted to RGB
# reshaped and normalized
# Test Accuracy = 0.9730

# %%
# VISUALIZATION
#Randonly selected images and their predicted labels

_, ax = plt.subplots( len(ls)//5, 5, figsize=(6,5))
row, col = 0, 0  
for i, idx in enumerate(ls):
    img =  X_test[idx]
    ax[row, col].imshow(img, cmap='gray')
    annot = 'pred:'+str( int(prediction_test[i])) +'|True:'+ str(y_test[idx])
    ax[row, col].annotate(annot, xy=(0, 5), color='black', fontsize='7', bbox=dict(boxstyle="round", fc="0.8"))

    ax[row,col].axis('off')
    col += 1
    if col == 5:
        row += 1
        col = 0
plt.show()

# %% [markdown]
# ### Acquiring New Images

# %% [markdown]
# The 10 images shown below are real photos (as opposed to cliparts) of traffic signs. The images were randomly selected, that is to say that I did not look for traffic signs from a particular country. The only bias was to use real scene images, i.e where the background can be cars, trees, etc...similarly to real situation application.
# Because my model was trained on German Traffic signs, it is likely that it would have difficulties classifying  class of signs that were not present in the train dataset.

# %%
import os

IMG_HEIGHT = 32
IMG_WIDTH = 32

def get_list_files(my_dir, f_ext):
    list_f = []
    for file in os.listdir(my_dir):
        if file.endswith("."+f_ext):
            list_f.append(file)
    return list_f

my_dir = 'extra'
file_list = get_list_files(my_dir, 'png')

X_extra = np.zeros((len(file_list), IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH), dtype='uint8')

for idx, file in enumerate(file_list):
    img = cv2.imread(my_dir+'/'+file) #opencv opens images in BGR format
    img = cv2.resize(img,(32,32))
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) #convert to standard RGB
    X_extra[idx] = img

print('Extra dataset size: {} | Datatype: {}'.format(X_extra.shape, X_extra.dtype))
#Data pre-processing
X_extra_prep = pre_processed(X_extra).reshape(-1, IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH)
print('Pre-processed Extra dataset size: {} | Datatype: {}'.format(X_extra_prep.shape, X_extra_prep.dtype))
# Out:
# Extra dataset size: (10, 32, 32, 3) | Datatype: uint8
# (10, 32, 32, 3)
# converted to YCrCb
# converted to RGB
# reshaped and normalized
# Pre-processed Extra dataset size: (10, 32, 32, 3) | Datatype: float64

# %%
#Visualize images: original (left) and after pre-processing (right)

#initialize subplots
_, ax = plt.subplots( len(file_list), 2, figsize=(4,8))
col_plot = 0
print('Original (left) and pre-processed (right) images')
for i in range(len(X_extra)):
    img = X_extra[i]
    ax[i, col_plot].imshow(img)
    ax[i, col_plot].annotate(file_list[i], xy=(31, 5), color='black', fontsize='10')
    ax[i,col_plot].axis('off')
    col_plot += 1
    ax[i, col_plot].imshow(X_extra_prep[i,:,:,0], cmap='gray')
    ax[i,col_plot].axis('off')
    col_plot = 0
plt.show()
# Out:
# Original (left) and pre-processed (right) images

# %% [markdown]
# ### Performance on New Images

# %%
### Inference
feed_dict = {x: X_extra_prep, keep_prob: 1,  k_p_conv: 1}
k_top = 5

with tf.Session() as sess:
    loader = tf.train.import_meta_graph('.\\traffic_model'+model_nbr+'.meta')
    loader.restore(sess, tf.train.latest_checkpoint('./'))
    pred_proba = sess.run(softmax_operation, feed_dict=feed_dict)
    prediction = np.argmax(pred_proba, 1)
    # top 5 probabilities
    top_k_values = tf.nn.top_k(softmax_operation, k_top)
    top_k_proba = sess.run([ softmax_operation, top_k_values], feed_dict=feed_dict)
### Feel free to use as many code cells as needed.

#Visualize image with predicted label
print('PREDICTION ON EXTRA DATA \t')
for i in range(len(X_extra)):
    plt.figure(figsize=(1,1))
    img = X_extra[i]
    plt.imshow(img)
    plt.title(sign_names[ prediction[i] ][1], fontsize=10)
    plt.axis('off')
    plt.show()
# Out:
# INFO:tensorflow:Restoring parameters from ./traffic_model200
# PREDICTION ON EXTRA DATA

# %% [markdown]
# ### Model Certainty - Softmax Probabilities

# %% [markdown]
# The model performs quite badly on the new dataset.

# %%
### TOP 5 PROBABILITIES: CERTAINTIES

#initialize subplots
_, ax = plt.subplots( len(file_list), 2, figsize=(4,8))
col_plot = 0
for i in range(len(X_extra)):
    img = X_extra[i]
    ax[i, col_plot].imshow(img)
    ax[i,col_plot].axis('off')
    col_plot += 1
    ax[i, col_plot].barh(-np.arange(k_top),top_k_proba[1][0][i], align='center')
    
    #annotations
    for k in range(k_top):
        text_pos = [top_k_proba[1][0][i][k]+.1, -(k+0.4) ]
        ax[i, col_plot].text( text_pos[0], text_pos[1], sign_names[top_k_proba[1][1][i][k]][1], fontsize=8)
    ax[i,col_plot].axis('off')
    col_plot = 0
plt.show()

# %% [markdown]
# ## Future work for improving the model
#
# 1. Try model cross validation when time permit.
# Parameters having impact on the training/validation processing include initialization parameters, dropout rate, learning rate/decay rate, data augmentation numbers, L2 parameters, etc.
#
# 2. Try different deep neural network models.
# What if the model becomes "deeper", how about other models like inception v4, inception-resnet v2. It'll be very interesting to see the outcome.

# %% [markdown]
# ### > **Note**: Once you have completed all of the code implementations and successfully answered each question above, you may finalize your work by exporting the iPython Notebook as an HTML document. You can do this by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
